# %% [markdown]
# <a href="https://colab.research.google.com/github/judgeadamu123-crypto/Judge-Ginasha-/blob/main/DTS_WEEK_3_Python_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT (Week 3)
#
# Submit your Jupyter Notebook (.ipynb) through your GitHub repository.

# %% [markdown]
# Student name;Judge Ginasha Adamu
#
# Department; Data science
#
# Faculty; Computing
#
# Course; DTS 103
#
# Mat number; UJ/2025/CP/0042

# %% [markdown]
# # ASSIGNMENT 1. Create a list of 5 student scores

# %%
scores = [91,88,76,68,80]
print(scores)
# Out:
# [91, 88, 76, 68, 80]

# %%
print(scores [0])
print(scores [2])
# Out:
# 91
# 76

# %%
for score in scores:
 print(score)
# Out:
# 91
# 88
# 76
# 68
# 80

# %% [markdown]
# # ASSIGNMENT 2. Compute the average score

# %%
total = 0
for score in scores:
    total = total + score

average = total / len(scores)

print("Average score:", average)
# Out:
# Average score: 80.6

# %% [markdown]
# # ASSIGNMENT 3. Find the highest score

# %%
highest = scores[0]
for score in scores:
    if score > highest:
        highest = score

print("highest scores:", highest)
# Out:
# highest scores: 91

# %% [markdown]
# # ASSIGNMENT 4. Create a dictionary with 5 students and scores

# %%
students = {
"S0001": 91,
"S0002": 88,
"S0003": 76,
"S0004": 68,
"S0005": 80
}
print(students)
# Out:
# {'S0001': 91, 'S0002': 88, 'S0003': 76, 'S0004': 68, 'S0005': 80}

# %% [markdown]
# # ASSIGNMENT 5. Find the highest scoring student

# %%
Highest_id = None
Highest_score = 0
for student_id in students:
    score = students[student_id]
    if score > Highest_score:
        Highest_score = score
        Highest_id = student_id

print("highest scoring student:", Highest_id)
print("Highest score:", Highest_score)
# Out:
# highest scoring student: S0001
# Highest score: 91

# %% [markdown]
# # ASSIGNMENT 6. Create a tuple of subjects

# %%
subjects = ("maths", "chemistry", "physics")
print(subjects)
print(subjects[0])
# Out:
# ('maths', 'chemistry', 'physics')
# maths

# %% [markdown]
# # ASSIGNMENT 7. Create a set of unique scores

# %%
scores_set = {30,45,67,87,45}

print(scores_set)
# Out:
# {67, 45, 30, 87}

# %% [markdown]
# Student name;Judge Ginasha Adamu
#
# Department; Data science
#
# Faculty; Computing
#
# Course; DTS 103
#
# Mat number; UJ/2025/CP/0042
